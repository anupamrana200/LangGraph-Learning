# %%
! pip install -U "psycopg[binary,pool]" langgraph langgraph-checkpoint-postgres
# Out:
# Requirement already satisfied: langgraph in D:\LangGraph\myvenv\Lib\site-packages (0.6.4)
# Collecting langgraph
#   Downloading langgraph-1.0.10-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: langgraph-checkpoint-postgres in D:\LangGraph\myvenv\Lib\site-packages (3.0.4)
# Requirement already satisfied: psycopg[binary,pool] in D:\LangGraph\myvenv\Lib\site-packages (3.3.3)
# Requirement already satisfied: typing-extensions>=4.6 in D:\LangGraph\myvenv\Lib\site-packages (from psycopg[binary,pool]) (4.14.1)
# Requirement already satisfied: tzdata in D:\LangGraph\myvenv\Lib\site-packages (from psycopg[binary,pool]) (2025.2)
# Collecting psycopg-binary==3.3.3 (from psycopg[binary,pool])
#   Using cached psycopg_binary-3.3.3-cp311-cp311-win_amd64.whl.metadata (2.7 kB)
# Requirement already satisfied: psycopg-pool in D:\LangGraph\myvenv\Lib\site-packages (from psycopg[binary,pool]) (3.3.0)
# Requirement already satisfied: langchain-core>=0.1 in D:\LangGraph\myvenv\Lib\site-packages (from langgraph) (0.3.74)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in D:\LangGraph\myvenv\Lib\site-packages (from langgraph) (2.1.2)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.8 (from langgraph)
#   Downloading langgraph_prebuilt-1.0.8-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph)
#   Downloading langgraph_sdk-0.3.9-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: pydantic>=2.7.4 in D:\LangGraph\myvenv\Lib\site-packages (from langgraph) (2.11.7)
# Requirement already satisfied: xxhash>=3.5.0 in D:\LangGraph\myvenv\Lib\site-packages (from langgraph) (3.5.0)
# Requirement already satisfied: ormsgpack>=1.10.0 in D:\LangGraph\myvenv\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph) (1.12.2)
# Collecting langchain-core>=0.1 (from langgraph)
#   Downloading langchain_core-1.2.17-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: httpx>=0.25.2 in D:\LangGraph\myvenv\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.28.1)
# Collecting orjson>=3.11.5 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph)
#   Downloading orjson-3.11.7-cp311-cp311-win_amd64.whl.metadata (43 kB)
# Requirement already satisfied: anyio in D:\LangGraph\myvenv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (4.10.0)
# Requirement already satisfied: certifi in D:\LangGraph\myvenv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in D:\LangGraph\myvenv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.0.9)
# Requirement already satisfied: idna in D:\LangGraph\myvenv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (3.10)
# Requirement already satisfied: h11>=0.16 in D:\LangGraph\myvenv\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in D:\LangGraph\myvenv\Lib\site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in D:\LangGraph\myvenv\Lib\site-packages (from langchain-core>=0.1->langgraph) (0.4.13)
# Requirement already satisfied: packaging>=23.2.0 in D:\LangGraph\myvenv\Lib\site-packages (from langchain-core>=0.1->langgraph) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in D:\LangGraph\myvenv\Lib\site-packages (from langchain-core>=0.1->langgraph) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in D:\LangGraph\myvenv\Lib\site-packages (from langchain-core>=0.1->langgraph) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in D:\LangGraph\myvenv\Lib\site-packages (from langchain-core>=0.1->langgraph) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in D:\LangGraph\myvenv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in D:\LangGraph\myvenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in D:\LangGraph\myvenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.32.4)
# Requirement already satisfied: zstandard>=0.23.0 in D:\LangGraph\myvenv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in D:\LangGraph\myvenv\Lib\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in D:\LangGraph\myvenv\Lib\site-packages (from pydantic>=2.7.4->langgraph) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in D:\LangGraph\myvenv\Lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in D:\LangGraph\myvenv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in D:\LangGraph\myvenv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.5.0)
# Requirement already satisfied: sniffio>=1.1 in D:\LangGraph\myvenv\Lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph) (1.3.1)
# Using cached psycopg_binary-3.3.3-cp311-cp311-win_amd64.whl (3.6 MB)
# Downloading langgraph-1.0.10-py3-none-any.whl (160 kB)
# Downloading langgraph_prebuilt-1.0.8-py3-none-any.whl (35 kB)
# Downloading langgraph_sdk-0.3.9-py3-none-any.whl (90 kB)
# Downloading langchain_core-1.2.17-py3-none-any.whl (502 kB)
# Downloading orjson-3.11.7-cp311-cp311-win_amd64.whl (124 kB)
# Installing collected packages: psycopg-binary, orjson, langgraph-sdk, langchain-core, langgraph-prebuilt, langgraph
#
#   Attempting uninstall: orjson
#
#     Found existing installation: orjson 3.11.1
#
#     Uninstalling orjson-3.11.1:
#
#       Successfully uninstalled orjson-3.11.1
#
#    ------ --------------------------------- 1/6 [orjson]
#    ------ --------------------------------- 1/6 [orjson]
#    ------ --------------------------------- 1/6 [orjson]
#    ------ --------------------------------- 1/6 [orjson]
#    ------ --------------------------------- 1/6 [orjson]
#    ------ --------------------------------- 1/6 [orjson]
#    ------ --------------------------------- 1/6 [orjson]
#    ------ --------------------------------- 1/6 [orjson]
#    ------ --------------------------------- 1/6 [orjson]
#    ------ --------------------------------- 1/6 [orjson]
#    ------ --------------------------------- 1/6 [orjson]
#    ------ --------------------------------- 1/6 [orjson]
#    ------ --------------------------------- 1/6 [orjson]
#    ------ --------------------------------- 1/6 [orjson]
#    ------ --------------------------------- 1/6 [orjson]
#    ------ --------------------------------- 1/6 [orjson]
#    ------ --------------------------------- 1/6 [orjson]
#    ------ --------------------------------- 1/6 [orjson]
#    ------ --------------------------------- 1/6 [orjson]
#   Attempting uninstall: langgraph-sdk
#    ------ --------------------------------- 1/6 [orjson]
#     Found existing installation: langgraph-sdk 0.2.0
#    ------ --------------------------------- 1/6 [orjson]
#     Uninstalling langgraph-sdk-0.2.0:
#    ------ --------------------------------- 1/6 [orjson]
#       Successfully uninstalled langgraph-sdk-0.2.0
#    ------ --------------------------------- 1/6 [orjson]
#    ------------- -------------------------- 2/6 [langgraph-sdk]
#    ------------- -------------------------- 2/6 [langgraph-sdk]
#    ------------- -------------------------- 2/6 [langgraph-sdk]
#    ------------- -------------------------- 2/6 [langgraph-sdk]
#    ------------- -------------------------- 2/6 [langgraph-sdk]
#    ------------- -------------------------- 2/6 [langgraph-sdk]
#   Attempting uninstall: langchain-core
#    ------------- -------------------------- 2/6 [langgraph-sdk]
#     Found existing installation: langchain-core 0.3.74
#    ------------- -------------------------- 2/6 [langgraph-sdk]
#     Uninstalling langchain-core-0.3.74:
#    ------------- -------------------------- 2/6 [langgraph-sdk]
#       Successfully uninstalled langchain-core-0.3.74
#    ------------- -------------------------- 2/6 [langgraph-sdk]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#   Attempting uninstall: langgraph-prebuilt
#    -------------------- ------------------- 3/6 [langchain-core]
#     Found existing installation: langgraph-prebuilt 0.6.4
#    -------------------- ------------------- 3/6 [langchain-core]
#     Uninstalling langgraph-prebuilt-0.6.4:
#    -------------------- ------------------- 3/6 [langchain-core]
#       Successfully uninstalled langgraph-prebuilt-0.6.4
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------------- ------------- 4/6 [langgraph-prebuilt]
#   Attempting uninstall: langgraph
#    -------------------------- ------------- 4/6 [langgraph-prebuilt]
#     Found existing installation: langgraph 0.6.4
#    -------------------------- ------------- 4/6 [langgraph-prebuilt]
#     Uninstalling langgraph-0.6.4:
#    -------------------------- ------------- 4/6 [langgraph-prebuilt]
#       Successfully uninstalled langgraph-0.6.4
#    -------------------------- ------------- 4/6 [langgraph-prebuilt]
#    --------------------------------- ------ 5/6 [langgraph]
#    --------------------------------- ------ 5/6 [langgraph]
#    --------------------------------- ------ 5/6 [langgraph]
#    --------------------------------- ------ 5/6 [langgraph]
#    --------------------------------- ------ 5/6 [langgraph]
#    --------------------------------- ------ 5/6 [langgraph]
#    --------------------------------- ------ 5/6 [langgraph]
#    --------------------------------- ------ 5/6 [langgraph]
#    ---------------------------------------- 6/6 [langgraph]
#
# Successfully installed langchain-core-1.2.17 langgraph-1.0.10 langgraph-prebuilt-1.0.8 langgraph-sdk-0.3.9 orjson-3.11.7 psycopg-binary-3.3.3
#   WARNING: Failed to remove contents in a temporary directory 'D:\LangGraph\myvenv\Lib\site-packages\~rjson'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.27 requires langchain-core<1.0.0,>=0.3.72, but you have langchain-core 1.2.17 which is incompatible.
# langchain-community 0.3.27 requires langchain-core<1.0.0,>=0.3.66, but you have langchain-core 1.2.17 which is incompatible.
# langchain-openai 0.3.29 requires langchain-core<1.0.0,>=0.3.74, but you have langchain-core 1.2.17 which is incompatible.
# langchain-text-splitters 0.3.9 requires langchain-core<1.0.0,>=0.3.72, but you have langchain-core 1.2.17 which is incompatible.

# %%
from dotenv import load_dotenv
load_dotenv()

import uuid
from typing import List
from pydantic import BaseModel, Field

from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage
from langchain_core.runnables import RunnableConfig

from langgraph.graph import StateGraph, START, END, MessagesState
from langgraph.store.postgres import PostgresStore
from langgraph.store.base import BaseStore

# %%
# ----------------------------
# 2) System prompt
# ----------------------------
SYSTEM_PROMPT_TEMPLATE = """You are a helpful assistant with memory capabilities.
If user-specific memory is available, use it to personalize 
your responses based on what you know about the user.

Your goal is to provide relevant, friendly, and tailored 
assistance that reflects the user’s preferences, context, and past interactions.

If the user’s name or relevant personal context is available, always personalize your responses by:
    – Always Address the user by name (e.g., "Sure, Nitish...") when appropriate
    – Referencing known projects, tools, or preferences (e.g., "your MCP server python based project")
    – Adjusting the tone to feel friendly, natural, and directly aimed at the user

Avoid generic phrasing when personalization is possible.

Use personalization especially in:
    – Greetings and transitions
    – Help or guidance tailored to tools and frameworks the user uses
    – Follow-up messages that continue from past context

Always ensure that personalization is based only on known user details and not assumed.

In the end suggest 3 relevant further questions based on the current response and user profile

The user’s memory (which may be empty) is provided as: {user_details_content}
"""

# %%
# ----------------------------
# 3) Memory extraction LLM
# ----------------------------
memory_llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

class MemoryItem(BaseModel):
    text: str = Field(description="Atomic user memory")
    is_new: bool = Field(description="True if new, false if duplicate")

class MemoryDecision(BaseModel):
    should_write: bool
    memories: List[MemoryItem] = Field(default_factory=list)
    
memory_extractor = memory_llm.with_structured_output(MemoryDecision)

# %%
MEMORY_PROMPT = """You are responsible for updating and maintaining accurate user memory.

CURRENT USER DETAILS (existing memories):
{user_details_content}

TASK:
- Review the user's latest message.
- Extract user-specific info worth storing long-term (identity, stable preferences, ongoing projects/goals).
- For each extracted item, set is_new=true ONLY if it adds NEW information compared to CURRENT USER DETAILS.
- If it is basically the same meaning as something already present, set is_new=false.
- Keep each memory as a short atomic sentence.
- No speculation; only facts stated by the user.
- If there is nothing memory-worthy, return should_write=false and an empty list.
"""

# %%
# ----------------------------
# 3) Nodes
# ----------------------------
def remember_node(state: MessagesState, config: RunnableConfig, *, store: BaseStore):
    user_id = config["configurable"]["user_id"]
    ns = ("user", user_id, "details")

    # existing memory (all items under namespace)
    items = store.search(ns)
    existing = "\n".join(it.value.get("data", "") for it in items) if items else "(empty)"

    # latest user message
    last_text = state["messages"][-1].content

    decision: MemoryDecision = memory_extractor.invoke(
        [
            SystemMessage(content=MEMORY_PROMPT.format(user_details_content=existing)),
            {"role": "user", "content": last_text},
        ]
    )

    if decision.should_write:
        for mem in decision.memories:
            if mem.is_new and mem.text.strip():
                store.put(ns, str(uuid.uuid4()), {"data": mem.text.strip()})

    return {}

# %%
chat_llm = ChatOpenAI(model="gpt-4o-mini")

def chat_node(state: MessagesState, config: RunnableConfig, *, store: BaseStore):
    user_id = config["configurable"]["user_id"]
    ns = ("user", user_id, "details")

    items = store.search(ns)
    user_details = "\n".join(it.value.get("data", "") for it in items) if items else ""

    system_msg = SystemMessage(
        content=SYSTEM_PROMPT_TEMPLATE.format(user_details_content=user_details or "(empty)")
    )

    response = chat_llm.invoke([system_msg] + state["messages"])
    return {"messages": [response]}

# %%
# ----------------------------
# 4) Build graph
# ----------------------------
builder = StateGraph(MessagesState)
builder.add_node("remember", remember_node)
builder.add_node("chat", chat_node)
builder.add_edge(START, "remember")
builder.add_edge("remember", "chat")
builder.add_edge("chat", END)

# %%
# ----------------------------
# 5) Use PostgresStore (PERSISTENT LTM)
# ----------------------------
DB_URI = "postgresql://postgres:postgres@localhost:5442/postgres?sslmode=disable"

with PostgresStore.from_conn_string(DB_URI) as store:
    # IMPORTANT: run ONCE the first time you use this database
    store.setup()

    graph = builder.compile(store=store)

    config = {"configurable": {"user_id": "u1"}}

    graph.invoke({"messages": [{"role": "user", "content": "Hi, my name is Nitish"}]}, config)
    graph.invoke({"messages": [{"role": "user", "content": "I teach AI on YouTube"}]}, config)

    out = graph.invoke({"messages": [{"role": "user", "content": "Explain GenAI simply"}]}, config)
    print(out["messages"][-1].content)

    print("\n--- Stored Memories (from Postgres) ---")
    for it in store.search(("user", "u1", "details")):
        print(it.value["data"])
# Out:
# Sure, Nitish!
#
# Generative AI, or GenAI, refers to a type of artificial intelligence that can create new content from scratch. This can include text, images, music, and even videos. It works by learning patterns from existing data and then generating new examples that are similar but not identical to the original training data.
#
# Think of it like training an artist with various styles and then letting that artist create new pieces that blend those styles together. For example, if you train a GenAI model on a set of texts about AI concepts, it can generate new explanations or stories related to AI.
#
# Does that help clarify things? If you’d like more details or real-world applications, just let me know!
#
# Here are a few further questions for you:
# 1. Are there specific applications of GenAI you’re interested in exploring for your teaching on YouTube?
# 2. Would you like examples of projects that utilize GenAI?
# 3. Do you have any particular challenges in explaining AI concepts that I could assist you with?
#
# --- Stored Memories (from Postgres) ---
# Nitish teaches AI on YouTube.
# User's name is Nitish.

# %% [markdown]
# # Check Persistence

# %%
from langgraph.store.postgres import PostgresStore

DB_URI = "postgresql://postgres:postgres@localhost:5442/postgres?sslmode=disable"

with PostgresStore.from_conn_string(DB_URI) as store:
    ns = ("user", "u1", "details")
    items = store.search(ns)

for it in items:
    print(it.value["data"])
# Out:
# Nitish teaches AI on YouTube.
# User's name is Nitish.
