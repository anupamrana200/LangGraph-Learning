# %%
from google import genai

client = genai.Client(api_key="")

resp = client.models.generate_content(
    model="gemini-2.5-flash-image",
    contents="A simple diagram of a transformer architecture",
)

print(resp)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[1], line 5
#       1 from google import genai
#       3 client = genai.Client(api_key="AIzaSyA90sAG0-YhdERtOS1BWToJD3CSOmG5bEI")
# ----> 5 resp = client.models.generate_content(
#       6     model="gemini-2.5-flash-image",
#       7     contents="A simple diagram of a transformer architecture",
#       8 )
#      10 print(resp)
#
# File d:\LangGraph\myvenv\Lib\site-packages\google\genai\models.py:5709, in Models.generate_content(self, model, contents, config)
#    5707 while remaining_remote_calls_afc > 0:
#    5708   i += 1
# -> 5709   response = self._generate_content(
#    5710       model=model, contents=contents, config=parsed_config
#    5711   )
#    5713   function_map = _extra_utils.get_function_map(parsed_config)
#    5714   if not function_map:
#
# ...
